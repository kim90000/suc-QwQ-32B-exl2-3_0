# %%
# !git clone https://github.com/turboderp/exui
# !cd exui && pip install -r requirements.txt
# !git clone https://github.com/turboderp/exllamav2
# !cd exllamav2 && python setup.py install --user

# %%
# !git clone https://github.com/turboderp/exllamav2
# !cd exllamav2 && pip install -r requirements.txt
# Out:
# Cloning into 'exllamav2'...
# remote: Enumerating objects: 8145, done.
# remote: Counting objects: 100% (3467/3467), done.
# remote: Compressing objects: 100% (974/974), done.
# remote: Total 8145 (delta 2565), reused 2521 (delta 2493), pack-reused 4678 (from 2)
# Receiving objects: 100% (8145/8145), 21.93 MiB | 11.50 MiB/s, done.
# Resolving deltas: 100% (5870/5870), done.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.8/422.8 kB 24.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 50.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 68.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 48.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.5 MB/s eta 0:00:00
# ...

# %%
# !pip install exllamav2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 40.6 MB/s eta 0:00:00
# ...

# %%
ReadyArt/Llama_3.x_70b_Hexagon_Purple_V2_EXL2_2.5bpw_H8

# %%
# !huggingface-cli download ReadyArt/Llama_3.x_70b_Hexagon_Purple_V2_EXL2_2.5bpw_H8 --revision 2.5bpw_H8 --local-dir Llama_3.x_70b_Hexagon_Purple_V2_EXL2_2.5bpw_H8
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py", line 409, in hf_raise_for_status
#     response.raise_for_status()
#   File "/usr/local/lib/python3.11/dist-packages/requests/models.py", line 1024, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/api/models/ReadyArt/Llama_3.x_70b_Hexagon_Purple_V2_EXL2_2.5bpw_H8/revision/2.5bpw_H8
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/huggingface-cli", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/huggingface_hub/commands/huggingface_cli.py", line 57, in main
#     service.run()
#   File "/usr/local/lib/python3.11/dist-packages/huggingface_hub/commands/download.py", line 153, in run
# ...

# %% [markdown]
# شغال

# %% [markdown]
# https://huggingface.co/ReadyArt

# %%
# !huggingface-cli download ReadyArt/Llama_3.x_70b_Hexagon_Purple_V2_EXL2_2.5bpw_H8 --revision main --local-dir Llama_3.x_70b_Hexagon_Purple_V2_EXL2_2.5bpw_H8
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
# output-00003-of-00003.safetensors:  19% 1.44G/7.42G [00:59<04:04, 24.5MB/s]
# output-00002-of-00003.safetensors:  16% 1.39G/8.55G [00:59<05:04, 23.5MB/s]
#
#
#
# output-00003-of-00003.safetensors:  20% 1.45G/7.42G [00:59<04:03, 24.5MB/s]
#
#
# output-00001-of-00003.safetensors:  16% 1.39G/8.59G [00:59<05:27, 22.0MB/s]
# output-00002-of-00003.safetensors:  16% 1.41G/8.55G [01:00<05:03, 23.5MB/s]
#
#
#
# output-00003-of-00003.safetensors:  20% 1.46G/7.42G [00:59<04:03, 24.5MB/s]
#
#
# output-00001-of-00003.safetensors:  16% 1.41G/8.59G [01:00<05:20, 22.4MB/s]
# output-00002-of-00003.safetensors:  17% 1.42G/8.55G [01:00<05:03, 23.5MB/s]
#
#
#
# output-00003-of-00003.safetensors:  20% 1.47G/7.42G [01:00<04:03, 24.5MB/s]
#
#
# output-00001-of-00003.safetensors:  16% 1.42G/8.59G [01:00<05:14, 22.8MB/s]
# output-00002-of-00003.safetensors:  17% 1.43G/8.55G [01:01<05:02, 23.5MB/s]
#
#
#
# ...

# %%
# !huggingface-cli download ReadyArt/Llama_3.x_70b_Hexagon_Purple_V2_EXL2_2.5bpw_H8 --local-dir Llama_3.x_70b_Hexagon_Purple_V2_EXL2_2.5bpw_H8

# %%
# %cd /content/exllamav2
# !python examples/chat.py -m /content/Llama_3.x_70b_Hexagon_Purple_V2_EXL2_2.5bpw_H8 -mode llama -cq4 -nfa -l 10
# Out:
# /content/exllamav2
#  -- Model: /content/Llama_3.x_70b_Hexagon_Purple_V2_EXL2_2.5bpw_H8
#  -- Options: ['length: 10', 'no_flash_attn']
#  -- Loading tokenizer...
#  -- Loading model...
#  -- Loading model...
# Traceback (most recent call last):
#   File "/content/exllamav2/examples/chat.py", line 159, in <module>
#     model_init.post_init_load(model, args, allow_auto_split = True)
#   File "/usr/local/lib/python3.11/dist-packages/exllamav2/model_init.py", line 182, in post_init_load
#     model.load(split, progress = progress)
#   File "/usr/local/lib/python3.11/dist-packages/exllamav2/model.py", line 307, in load
#     for item in f:
#   File "/usr/local/lib/python3.11/dist-packages/exllamav2/model.py", line 335, in load_gen
#     module.load()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
ReadyArt/Llama_3.x_70b_Hexagon_Purple_V2_EXL2_2.0bpw_H8

# %%
# %cd /content
# Out:
# /content

# %%
# !huggingface-cli download ReadyArt/Llama_3.x_70b_Hexagon_Purple_V2_EXL2_2.0bpw_H8 --revision main --local-dir Llama_3.x_70b_Hexagon_Purple_V2_EXL2_2.0bpw_H8
# Out:
# Streaming output truncated to the last 5000 lines.
# output-00003-of-00003.safetensors:  23% 1.14G/5.04G [00:47<02:41, 24.1MB/s]
#
#
# output-00002-of-00003.safetensors:  13% 1.13G/8.54G [00:48<05:09, 23.9MB/s]
#
# output-00001-of-00003.safetensors:  13% 1.15G/8.55G [00:48<05:07, 24.1MB/s]
#
#
#
# output-00003-of-00003.safetensors:  23% 1.15G/5.04G [00:48<02:41, 24.1MB/s]
#
#
# output-00002-of-00003.safetensors:  13% 1.14G/8.54G [00:48<05:08, 24.0MB/s]
#
# output-00001-of-00003.safetensors:  14% 1.16G/8.55G [00:48<05:07, 24.1MB/s]
#
#
#
# output-00003-of-00003.safetensors:  23% 1.16G/5.04G [00:48<02:40, 24.1MB/s]
#
#
# output-00002-of-00003.safetensors:  14% 1.15G/8.54G [00:48<05:08, 23.9MB/s]
#
# output-00001-of-00003.safetensors:  14% 1.17G/8.55G [00:49<05:06, 24.0MB/s]
#
#
#
# output-00003-of-00003.safetensors:  23% 1.17G/5.04G [00:49<02:40, 24.1MB/s]
#
#
# output-00002-of-00003.safetensors:  14% 1.16G/8.54G [00:49<05:08, 23.9MB/s]
#
# ...

# %%
# %cd /content/exllamav2
# !python examples/chat.py -m /content/Llama_3.x_70b_Hexagon_Purple_V2_EXL2_2.0bpw_H8 -mode llama -cq4 -nfa -l 1
# Out:
# /content/exllamav2
#  -- Model: /content/Llama_3.x_70b_Hexagon_Purple_V2_EXL2_2.0bpw_H8
#  -- Options: ['length: 1', 'no_flash_attn']
#  -- Loading tokenizer...
#  -- Loading model...
#  -- Loading model...
# Traceback (most recent call last):
#   File "/content/exllamav2/examples/chat.py", line 159, in <module>
#     model_init.post_init_load(model, args, allow_auto_split = True)
#   File "/usr/local/lib/python3.11/dist-packages/exllamav2/model_init.py", line 182, in post_init_load
#     model.load(split, progress = progress)
#   File "/usr/local/lib/python3.11/dist-packages/exllamav2/model.py", line 307, in load
#     for item in f:
#   File "/usr/local/lib/python3.11/dist-packages/exllamav2/model.py", line 335, in load_gen
#     module.load()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
# ...
